# %% [markdown]
# I'll begin by creating a dataframe for the historic arrest dataset first then the year-to-date data

# %%
import pandas as pd
historic = pd.read_csv('/content/NYPD_Arrests_Data__Historic__20240914.csv')

# %%
historic.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   220756993  11/19/2020  155.0        RAPE 2  104.0        RAPE  PL 1303001
# 1   221995093  12/18/2020  177.0  SEXUAL ABUSE  116.0  SEX CRIMES  PL 1306503
# 2   221558560  12/09/2020  157.0        RAPE 1  104.0        RAPE  PL 1303501
# 3   217890363  09/15/2020    NaN           NaN    NaN         NaN  PL 2650022
# 4   219517698  10/21/2020  153.0        RAPE 3  104.0        RAPE  PL 1302502
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 0          F           B               41                0.0     18-24
# 1          F           K               84                0.0     45-64
# 2          F           S              120                0.0       <18
# 3          M           B               44                0.0     25-44
# 4          F           Q              112                0.0     25-44
#
#   PERP_SEX       PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0        M           BLACK   1013232.0    236725.0  40.816392 -73.895296
# 1        M           WHITE    989013.0    192652.0  40.695469 -73.982825
# 2        M           BLACK    962748.0    174174.0  40.644726 -74.077483
# 3        M           BLACK   1009412.0    245306.0  40.839956 -73.909065
# 4        M  WHITE HISPANIC   1025420.0    202485.0  40.722364 -73.851474
#
#                                          Lon_Lat
# 0  POINT (-73.89529641399997 40.816391847000034)
# 1   POINT (-73.98282507899995 40.69546894100006)
# 2   POINT (-74.07748315899995 40.64472613100002)
# 3   POINT (-73.90906496999997 40.83995593800007)
# 4   POINT (-73.85147389399998 40.72236368700004)

# %%
ytd = pd.read_csv('/content/NYPD_Arrest_Data__Year_to_Date__20240914.csv')

# %%
ytd.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   279884335  01/03/2024  153.0                    RAPE 3  104.0
# 1   279876234  01/03/2024  105.0         STRANGULATION 1ST  106.0
# 2   279939192  01/04/2024  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
# 3   280561026  01/15/2024  203.0      TRESPASS 3, CRIMINAL  352.0
# 4   280084387  01/07/2024  223.0  BURGLARY,RESIDENCE,NIGHT  107.0
#
#            OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0               RAPE  PL 1302503          F           K               77
# 1     FELONY ASSAULT  PL 1211200          F           Q              101
# 2     FELONY ASSAULT  PL 1201001          F           K               83
# 3  CRIMINAL TRESPASS  PL 140100A          M           S              121
# 4           BURGLARY  PL 1403002          F           Q              107
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# 0                  0     45-64        M     BLACK     1003509      185018
# 1                  0     25-44        M     BLACK     1053648      158969
# 2                  0     45-64        M     BLACK     1007127      193705
# 3                  0     18-24        M     BLACK      942827      166373
# 4                  0     45-64        M     BLACK     1036732      206997
#
#     Latitude  Longitude                    New Georeferenced Column
# 0  40.674496 -73.930571  POINT (-73.9305713255961 40.6744956865259)
# 1  40.602740 -73.750081                 POINT (-73.750081 40.60274)
# 2  40.698323 -73.917495                POINT (-73.917495 40.698323)
# 3  40.623238 -74.149217                POINT (-74.149217 40.623238)
# 4  40.734681 -73.810626                POINT (-73.810626 40.734681)

# %% [markdown]
# # Question 1
#
# Will begin by getting the number of arrests for each year

# %%
historic['ARREST_DATE'] = pd.to_datetime(historic['ARREST_DATE'])
years = [2019, 2020, 2021, 2022, 2023]
f_historic = historic[historic['ARREST_DATE'].dt.year.isin(years)]

# %%
ytd['ARREST_DATE'] = pd.to_datetime(ytd['ARREST_DATE'])
years2 = [2024]
f_ytd = ytd[ytd['ARREST_DATE'].dt.year.isin(years2)] # just to make sure

# %%
f_historic.head(10)
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC  \
# 0    220756993  2020-11-19  155.0        RAPE 2  104.0        RAPE
# 1    221995093  2020-12-18  177.0  SEXUAL ABUSE  116.0  SEX CRIMES
# 2    221558560  2020-12-09  157.0        RAPE 1  104.0        RAPE
# 3    217890363  2020-09-15    NaN           NaN    NaN         NaN
# 4    219517698  2020-10-21  153.0        RAPE 3  104.0        RAPE
# 5    218151681  2020-09-21  157.0        RAPE 1  104.0        RAPE
# 7    215001943  2020-07-07  153.0        RAPE 3  104.0        RAPE
# 8    215508944  2020-07-20  263.0   ARSON 2,3,4  114.0       ARSON
# 9    217233706  2020-08-31  153.0        RAPE 3  104.0        RAPE
# 10   217147644  2020-08-28  157.0        RAPE 1  104.0        RAPE
#
#       LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0   PL 1303001          F           B               41                0.0
# 1   PL 1306503          F           K               84                0.0
# 2   PL 1303501          F           S              120                0.0
# 3   PL 2650022          M           B               44                0.0
# 4   PL 1302502          F           Q              112                0.0
# 5   PL 1303501          F           K               77                0.0
# 7   PL 1302503          F           B               41                0.0
# 8   PL 1500500          F           S              123                0.0
# 9   PL 1302503          F           K               77                0.0
# 10  PL 1303503          F           Q              105                0.0
#
#    AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 0      18-24        M           BLACK   1013232.0    236725.0  40.816392
# 1      45-64        M           WHITE    989013.0    192652.0  40.695469
# 2        <18        M           BLACK    962748.0    174174.0  40.644726
# 3      25-44        M           BLACK   1009412.0    245306.0  40.839956
# 4      25-44        M  WHITE HISPANIC   1025420.0    202485.0  40.722364
# 5      25-44        M           BLACK   1003606.0    185050.0  40.674583
# 7      25-44        M           BLACK   1013232.0    236725.0  40.816392
# 8        <18        M           WHITE    914928.0    125757.0  40.511586
# 9      18-24        M           BLACK   1003606.0    185050.0  40.674583
# 10     45-64        M           BLACK   1057636.0    203954.0  40.726187
#
#     Longitude                                        Lon_Lat
# 0  -73.895296  POINT (-73.89529641399997 40.816391847000034)
# 1  -73.982825   POINT (-73.98282507899995 40.69546894100006)
# 2  -74.077483   POINT (-74.07748315899995 40.64472613100002)
# 3  -73.909065   POINT (-73.90906496999997 40.83995593800007)
# 4  -73.851474   POINT (-73.85147389399998 40.72236368700004)
# 5  -73.930222   POINT (-73.93022154099998 40.67458330800008)
# 7  -73.895296  POINT (-73.89529641399997 40.816391847000034)
# 8  -74.249304   POINT (-74.24930372699998 40.51158633800003)
# 9  -73.930222   POINT (-73.93022154099998 40.67458330800008)
# 10 -73.735234   POINT (-73.73523390399998 40.72618713000002)

# %%
f_ytd.head(10)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   279884335  2024-01-03  153.0                    RAPE 3  104.0
# 1   279876234  2024-01-03  105.0         STRANGULATION 1ST  106.0
# 2   279939192  2024-01-04  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
# 3   280561026  2024-01-15  203.0      TRESPASS 3, CRIMINAL  352.0
# 4   280084387  2024-01-07  223.0  BURGLARY,RESIDENCE,NIGHT  107.0
# 5   280145864  2024-01-08  153.0                    RAPE 3  104.0
# 6   280513946  2024-01-14  157.0                    RAPE 1  104.0
# 7   280951544  2024-01-23  153.0                    RAPE 3  104.0
# 8   280733020  2024-01-18  153.0                    RAPE 3  104.0
# 9   281708525  2024-02-05  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
#
#            OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0               RAPE  PL 1302503          F           K               77
# 1     FELONY ASSAULT  PL 1211200          F           Q              101
# 2     FELONY ASSAULT  PL 1201001          F           K               83
# 3  CRIMINAL TRESPASS  PL 140100A          M           S              121
# 4           BURGLARY  PL 1403002          F           Q              107
# 5               RAPE  PL 1302503          F           K               77
# 6               RAPE  PL 1303501          F           K               75
# 7               RAPE  PL 1302503          F           B               41
# 8               RAPE  PL 1302503          F           B               41
# 9     FELONY ASSAULT  PL 1200502          F           B               44
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  \
# 0                  0     45-64        M           BLACK     1003509
# 1                  0     25-44        M           BLACK     1053648
# 2                  0     45-64        M           BLACK     1007127
# 3                  0     18-24        M           BLACK      942827
# 4                  0     45-64        M           BLACK     1036732
# 5                  0     25-44        M           BLACK     1003509
# 6                  0     25-44        M           BLACK     1017036
# 7                  0     25-44        M  WHITE HISPANIC     1013037
# 8                  0     45-64        M           BLACK     1013037
# 9                  0     25-44        M           WHITE     1003462
#
#    Y_COORD_CD   Latitude  Longitude  \
# 0      185018  40.674496 -73.930571
# 1      158969  40.602740 -73.750081
# 2      193705  40.698323 -73.917495
# 3      166373  40.623238 -74.149217
# 4      206997  40.734681 -73.810626
# 5      185018  40.674496 -73.930571
# 6      183890  40.671360 -73.881811
# 7      236657  40.816206 -73.896001
# 8      236657  40.816206 -73.896001
# 9      242605  40.832551 -73.930574
#
#                      New Georeferenced Column
# 0  POINT (-73.9305713255961 40.6744956865259)
# 1                 POINT (-73.750081 40.60274)
# 2                POINT (-73.917495 40.698323)
# 3                POINT (-74.149217 40.623238)
# 4                POINT (-73.810626 40.734681)
# 5  POINT (-73.9305713255961 40.6744956865259)
# 6  POINT (-73.8818110231735 40.6713598203364)
# 7  POINT (-73.8960011932583 40.8162058439227)
# 8  POINT (-73.8960011932583 40.8162058439227)
# 9                POINT (-73.930574 40.832551)

# %%
data2019 = f_historic[f_historic['ARREST_DATE'].dt.year == 2019]
data2019['ARREST_DATE'].value_counts().sum()
# Out:
# 214617

# %%
data2020 = f_historic[f_historic['ARREST_DATE'].dt.year == 2020]
data2020['ARREST_DATE'].value_counts().sum()
# Out:
# 140413

# %%
data2021 = f_historic[f_historic['ARREST_DATE'].dt.year == 2021]
data2021['ARREST_DATE'].value_counts().sum()
# Out:
# 155507

# %%
data2022 = f_historic[f_historic['ARREST_DATE'].dt.year == 2022]
data2022['ARREST_DATE'].value_counts().sum()
# Out:
# 189774

# %%
data2023 = f_historic[f_historic['ARREST_DATE'].dt.year == 2023]
data2023['ARREST_DATE'].value_counts().sum()
# Out:
# 226872

# %%
data2024 = f_ytd[f_ytd['ARREST_DATE'].dt.year == 2024]
data2024['ARREST_DATE'].value_counts().sum()
# Out:
# 128778

# %% [markdown]
# Visualizing the count of arrests per year

# %%
data = {'Year': [2019, 2020, 2021, 2022, 2023, 2024],
        'Count': [214617, 140413, 155507, 189774, 226872, 128778]}

df = pd.DataFrame(data)

# %%
import plotly.graph_objects as go

fig = go.Figure()

# all data except the last two points
fig.add_trace(go.Scatter(x=df['Year'][:-1], y=df['Count'][:-1], mode='lines+markers',
                         line=dict(color='blue'), name='past data'))

# last two points plotted with a dotted line
fig.add_trace(go.Scatter(x=df['Year'][-2:], y=df['Count'][-2:], mode='lines+markers',
                         line=dict(color='blue', dash='dot'), name='year-to-date'))

# titles and axes labels
fig.update_layout(title='Number of arrests per year (2019-2024)',
                  xaxis_title='Year',
                  yaxis_title='Count')

# interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36c51bce-be82-45a6-8a5e-0072659ecb2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36c51bce-be82-45a6-8a5e-0072659ecb2d")) {                    Plotly.newPlot(                        "36c51bce-be82-45a6-8a5e-0072659ecb2d",                        [{"line":{"color":"blue"},"mode":"lines+markers","name":"past data","x":[2019,2020,2021,2022,2023],"y":[214617,140413,155507,189774,226872],"type":"scatter"},{"line":{"color":"blue","dash":"dot"},"mode":"lines+markers","name":"year-to-date","x":[2023,2024],"y":[226872,128778],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidt ...

# %% [markdown]
# Q1: The graph above shows a general increase in the number of recorded arrests in NYC, with the exception of 2020 and year-to-date arrest counts available.

# %%
fig.write_html("Figure 1.html")
from google.colab import files
files.download("Figure 1.html")

# %% [markdown]
# # Question 2

# %%
f_historic.shape
f_ytd.shape
# Out:
# (128778, 19)

# %%
f_historic.head()
f_ytd.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   279884335  2024-01-03  153.0                    RAPE 3  104.0
# 1   279876234  2024-01-03  105.0         STRANGULATION 1ST  106.0
# 2   279939192  2024-01-04  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
# 3   280561026  2024-01-15  203.0      TRESPASS 3, CRIMINAL  352.0
# 4   280084387  2024-01-07  223.0  BURGLARY,RESIDENCE,NIGHT  107.0
#
#            OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0               RAPE  PL 1302503          F           K               77
# 1     FELONY ASSAULT  PL 1211200          F           Q              101
# 2     FELONY ASSAULT  PL 1201001          F           K               83
# 3  CRIMINAL TRESPASS  PL 140100A          M           S              121
# 4           BURGLARY  PL 1403002          F           Q              107
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# 0                  0     45-64        M     BLACK     1003509      185018
# 1                  0     25-44        M     BLACK     1053648      158969
# 2                  0     45-64        M     BLACK     1007127      193705
# 3                  0     18-24        M     BLACK      942827      166373
# 4                  0     45-64        M     BLACK     1036732      206997
#
#     Latitude  Longitude                    New Georeferenced Column
# 0  40.674496 -73.930571  POINT (-73.9305713255961 40.6744956865259)
# 1  40.602740 -73.750081                 POINT (-73.750081 40.60274)
# 2  40.698323 -73.917495                POINT (-73.917495 40.698323)
# 3  40.623238 -74.149217                POINT (-74.149217 40.623238)
# 4  40.734681 -73.810626                POINT (-73.810626 40.734681)

# %% [markdown]
# will have to handle NaN values in 'pd_desc' column

# %%
f_historic['PD_CD'].isna().sum()
# Out:
# 656

# %% [markdown]
# While 656 counts compared to almost a million rows means I could technically drop these NA values, it doesn't hurt the computation to replace them with the label U/NA/NR to represent unknown/not available/not reported

# %%
import numpy as np
f_historic['PD_DESC'] = f_historic['PD_DESC'].fillna('U/NA/NR')
f_ytd['PD_DESC'] = f_ytd['PD_DESC'].fillna('U/NA/NR')
# Out:
# <ipython-input-13-6f398aef11f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_historic['PD_DESC'] = f_historic['PD_DESC'].fillna('U/NA/NR')

# %% [markdown]
# combine the datasets to get 2019-2024 numbers together

# %%
combined = pd.concat([f_historic, f_ytd], axis=0)
combined = pd.DataFrame(combined)

# %%
combined.head()
combined.shape
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   220756993  2020-11-19  155.0        RAPE 2  104.0        RAPE  PL 1303001
# 1   221995093  2020-12-18  177.0  SEXUAL ABUSE  116.0  SEX CRIMES  PL 1306503
# 2   221558560  2020-12-09  157.0        RAPE 1  104.0        RAPE  PL 1303501
# 3   217890363  2020-09-15    NaN       U/NA/NR    NaN         NaN  PL 2650022
# 4   219517698  2020-10-21  153.0        RAPE 3  104.0        RAPE  PL 1302502
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 0          F           B               41                0.0     18-24
# 1          F           K               84                0.0     45-64
# 2          F           S              120                0.0       <18
# 3          M           B               44                0.0     25-44
# 4          F           Q              112                0.0     25-44
#
#   PERP_SEX       PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0        M           BLACK   1013232.0    236725.0  40.816392 -73.895296
# 1        M           WHITE    989013.0    192652.0  40.695469 -73.982825
# 2        M           BLACK    962748.0    174174.0  40.644726 -74.077483
# 3        M           BLACK   1009412.0    245306.0  40.839956 -73.909065
# 4        M  WHITE HISPANIC   1025420.0    202485.0  40.722364 -73.851474
#
#                                          Lon_Lat New Georeferenced Column
# 0  POINT (-73.89529641399997 40.816391847000034)                      NaN
# 1   POINT (-73.98282507899995 40.69546894100006)                      NaN
# 2   POINT (-74.07748315899995 40.64472613100002)                      NaN
# 3   POINT (-73.90906496999997 40.83995593800007)                      NaN
# 4   POINT (-73.85147389399998 40.72236368700004)                      NaN

# %% [markdown]
# (Lon_Lat is equivalent to New Georeferenced Column)

# %%
combined['PD_DESC'].value_counts()
# Out:
# PD_DESC
# ASSAULT 3                         122705
# LARCENY,PETIT FROM OPEN AREAS,    103575
# ASSAULT 2,1,UNCLASSIFIED           70396
# ROBBERY,OPEN AREA UNCLASSIFIED     51845
# TRAFFIC,UNCLASSIFIED MISDEMEAN     48400
#                                    ...
# ANARCHY,CRIMINAL                       1
# WOUNDS,REPORTING OF                    1
# FORTUNE TELLING                        1
# LOITERING,TRANSPORTATION FACIL         1
# PRIVACY,OFFENSES AGAINST,UNCLA         1
# Name: count, Length: 300, dtype: int64

# %%
# let's visualize this

import matplotlib.pyplot as plt

top5 = combined['PD_DESC'].value_counts().nlargest(5).sort_values(ascending=True)

top5.plot(kind='barh', color='skyblue')
plt.xlabel('Count')
plt.ylabel('Arrest Description')
plt.title('Top 5 Arrests in NYC from 2019-2024')
plt.show()

# %% [markdown]
# Let's also look at the top 5 over time

# %%
combined['ARREST_YEAR'] = combined['ARREST_DATE'].dt.year

# %%
arrest_counts = combined.groupby(['ARREST_YEAR', 'PD_DESC']).size().reset_index(name='count')
top5byyear = arrest_counts.groupby('ARREST_YEAR').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)

# %%
import plotly.express as px
#import plotly.graph_objects as go
#fig = go.Figure()

fig = px.line(top5byyear,
              x='ARREST_YEAR',
              y='count',
              color='PD_DESC',
              markers=True,
              title='Top 5 Arrest Types per Year',
              labels={'count': 'Number of Arrests', 'year': 'Year'})

# layout
fig.update_traces(connectgaps=False) #, selector=dict(type='scattermap'))
fig.update_layout(showlegend=True)

# Show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8cdb031-0167-4109-8742-4386b3c2245d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8cdb031-0167-4109-8742-4386b3c2245d")) {                    Plotly.newPlot(                        "d8cdb031-0167-4109-8742-4386b3c2245d",                        [{"hovertemplate":"PD_DESC=ASSAULT 3\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ASSAULT 3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"ASSAULT 3","orientation":"v","showlegend":true,"x":[2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[24513,17580,19766,22218,24744,13884],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=LARCENY,PETIT FROM OPEN AREAS,\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LARCENY,PETIT FROM OPEN AREAS,","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"LARCENY,PETIT FROM OPEN AREAS,","orientation":"v","showlegend":true,"x":[2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[21568,11374,13143,20558,23820,13112],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=TRAFFIC,UNCLASSIFIED MISDEMEAN\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TRAFFIC,UNCLASSIFIED MISDEMEAN","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"TRAFFIC,UNCLASSIFIED MISDEMEAN","orientation":"v","showlegend":true,"x":[2019,2023,2024],"xaxis":"x","y":[13624,11925,6793],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=ASSAULT 2,1,UNCLASSIFIED\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ASSAULT 2,1,UNCLASSIFIED","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"ASSAULT 2,1,UNCLASSIFIED","orientation":"v","showlegend":true,"x":[2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[11498,10059,11663,13929,15496,7751],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=CONTROLLED SUBSTANCE, POSSESSI\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CONTROLLED SUBSTANCE, POSSESSI","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"CONTROLLED SUBSTANCE, POSSESSI","orientation":"v","showlegend":true,"x":[2019],"xaxis":"x","y":[9235],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=ROBBERY,OPEN AREA UNCLASSIFIED\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ROBBERY,OPEN AREA UNCLASSIFIED","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"ROBBERY,OPEN AREA UNCLASSIFIED","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024],"xaxis":"x","y":[7911,7809,9896,11003,5991],"yaxis":"y","type":"scatter","connectgaps":false},{"hovertemplate":"PD_DESC=PUBLIC ADMINISTRATION,UNCLASSI\u003cbr\u003eARREST_YEAR=%{x}\u003cbr\u003eNumber of Arrests=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PUBLIC ADMINISTRATION,UNCLASSI","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"PUBLIC ADMINISTRATION,UNCLASSI","orientation":"v","showlegend":true,"x":[2020,2021,2022],"xaxis":"x","y":[6322,7135,8590],"yaxis":"y","type":"scatter","connectgaps":false}],            ...

# %%
fig.write_html("Figure 2.html")
files.download("Figure 2.html")

# %% [markdown]
# Q2: On 2019-2024 data as a whole, the top five arrests were for:
# 1. Assault 3
# 2. Larceny, Petit from open areas
# 3. Assault 2, 1, unclassified
# 4. Robbery, open area unclassified
# 5. Traffic, unclassified misdemeanor

# %% [markdown]
# # Question 3

# %% [markdown]
# outcome variable: total number of precinct arrests per month between 2019-2024
#
#
# null hypothesis: there is no difference in crime (arrests) between precinct 19 and precinct 73
#
# alternate hypothesis: there is a difference in crime between both precincts

# %%
combined.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   220756993  2020-11-19  155.0        RAPE 2  104.0        RAPE  PL 1303001
# 1   221995093  2020-12-18  177.0  SEXUAL ABUSE  116.0  SEX CRIMES  PL 1306503
# 2   221558560  2020-12-09  157.0        RAPE 1  104.0        RAPE  PL 1303501
# 3   217890363  2020-09-15    NaN       U/NA/NR    NaN         NaN  PL 2650022
# 4   219517698  2020-10-21  153.0        RAPE 3  104.0        RAPE  PL 1302502
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  ...  AGE_GROUP PERP_SEX  \
# 0          F           B               41  ...      18-24        M
# 1          F           K               84  ...      45-64        M
# 2          F           S              120  ...        <18        M
# 3          M           B               44  ...      25-44        M
# 4          F           Q              112  ...      25-44        M
#
#         PERP_RACE X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0           BLACK  1013232.0    236725.0  40.816392 -73.895296
# 1           WHITE   989013.0    192652.0  40.695469 -73.982825
# 2           BLACK   962748.0    174174.0  40.644726 -74.077483
# 3           BLACK  1009412.0    245306.0  40.839956 -73.909065
# 4  WHITE HISPANIC  1025420.0    202485.0  40.722364 -73.851474
#
#                                          Lon_Lat New Georeferenced Column  \
# 0  POINT (-73.89529641399997 40.816391847000034)                      NaN
# 1   POINT (-73.98282507899995 40.69546894100006)                      NaN
# 2   POINT (-74.07748315899995 40.64472613100002)                      NaN
# 3   POINT (-73.90906496999997 40.83995593800007)                      NaN
# 4   POINT (-73.85147389399998 40.72236368700004)                      NaN
#
#   ARREST_YEAR
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#
# [5 rows x 21 columns]

# %%
# prepare a new dataframe for analysis
q3 = combined
q3.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD       PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   220756993  2020-11-19  155.0        RAPE 2  104.0        RAPE  PL 1303001
# 1   221995093  2020-12-18  177.0  SEXUAL ABUSE  116.0  SEX CRIMES  PL 1306503
# 2   221558560  2020-12-09  157.0        RAPE 1  104.0        RAPE  PL 1303501
# 3   217890363  2020-09-15    NaN       U/NA/NR    NaN         NaN  PL 2650022
# 4   219517698  2020-10-21  153.0        RAPE 3  104.0        RAPE  PL 1302502
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  ...  AGE_GROUP PERP_SEX  \
# 0          F           B               41  ...      18-24        M
# 1          F           K               84  ...      45-64        M
# 2          F           S              120  ...        <18        M
# 3          M           B               44  ...      25-44        M
# 4          F           Q              112  ...      25-44        M
#
#         PERP_RACE X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0           BLACK  1013232.0    236725.0  40.816392 -73.895296
# 1           WHITE   989013.0    192652.0  40.695469 -73.982825
# 2           BLACK   962748.0    174174.0  40.644726 -74.077483
# 3           BLACK  1009412.0    245306.0  40.839956 -73.909065
# 4  WHITE HISPANIC  1025420.0    202485.0  40.722364 -73.851474
#
#                                          Lon_Lat New Georeferenced Column  \
# 0  POINT (-73.89529641399997 40.816391847000034)                      NaN
# 1   POINT (-73.98282507899995 40.69546894100006)                      NaN
# 2   POINT (-74.07748315899995 40.64472613100002)                      NaN
# 3   POINT (-73.90906496999997 40.83995593800007)                      NaN
# 4   POINT (-73.85147389399998 40.72236368700004)                      NaN
#
#   ARREST_YEAR
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#
# [5 rows x 21 columns]

# %%
# then I'll just take the data for both precincts in question
p19 = q3[q3['ARREST_PRECINCT'] == 19] #UES
p73 = q3[q3['ARREST_PRECINCT'] == 73] #BR
p19.head()
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 100      233911057  2021-09-22  166.0                        SODOMY 2  116.0
# 958056   244798609  2022-05-09  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 963509   240288465  2022-02-08  105.0               STRANGULATION 1ST  106.0
# 964201   239068696  2022-01-13  244.0   BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 964462   239872222  2022-01-30  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
#
#              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 100         SEX CRIMES  PL 1304501          F           M               19
# 958056   PETIT LARCENY  PL 1552500          M           M               19
# 963509  FELONY ASSAULT  PL 1211200          F           M               19
# 964201        BURGLARY  PL 1402000          F           M               19
# 964462   PETIT LARCENY  PL 1552500          M           M               19
#
#         ...  AGE_GROUP PERP_SEX       PERP_RACE X_COORD_CD  Y_COORD_CD  \
# 100     ...      25-44        M           BLACK   994276.0    218779.0
# 958056  ...      45-64        M           WHITE   996772.0    223148.0
# 963509  ...      18-24        M  WHITE HISPANIC   994296.0    218679.0
# 964201  ...      45-64        M           WHITE   994296.0    218679.0
# 964462  ...      25-44        M           WHITE   994244.0    218713.0
#
#          Latitude  Longitude                                       Lon_Lat  \
# 100     40.767177 -73.963807  POINT (-73.96380668299997 40.76717676000004)
# 958056  40.779159 -73.954784                  POINT (-73.954784 40.779159)
# 963509  40.766896 -73.963730                   POINT (-73.96373 40.766896)
# 964201  40.766896 -73.963730                   POINT (-73.96373 40.766896)
# 964462  40.766996 -73.963922    POINT (-73.9639223035387 40.7669956423899)
#
#        New Georeferenced Column ARREST_YEAR
# 100                         NaN        2021
# 958056                      NaN        2022
# 963509                      NaN        2022
# 964201                      NaN        2022
# 964462                      NaN        2022
#
# [5 rows x 21 columns]

# %%
# now I'll separate the data into monthly counts
p19['ARREST_MONTH'] = p19['ARREST_DATE'].dt.to_period('M')
p73['ARREST_MONTH'] = p73['ARREST_DATE'].dt.to_period('M')

mp19 = p19.groupby(['ARREST_MONTH', 'ARREST_PRECINCT']).size().reset_index(name='M_ARREST_NUM')
mp73 = p73.groupby(['ARREST_MONTH', 'ARREST_PRECINCT']).size().reset_index(name='M_ARREST_NUM')
# Out:
# <ipython-input-82-c36953a1ea51>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p19['ARREST_MONTH'] = p19['ARREST_DATE'].dt.to_period('M')
# <ipython-input-82-c36953a1ea51>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p73['ARREST_MONTH'] = p73['ARREST_DATE'].dt.to_period('M')

# %%
mp19.shape
mp73.shape
# Out:
#   ARREST_MONTH  ARREST_PRECINCT  M_ARREST_NUM
# 0      2019-01               19           201
# 1      2019-02               19           208
# 2      2019-03               19           187
# 3      2019-04               19           185
# 4      2019-05               19           224

# %%
# descriptive stats
mp19.describe()
# Out:
#        ARREST_PRECINCT  M_ARREST_NUM
# count             66.0     66.000000
# mean              19.0    162.696970
# std                0.0     42.398102
# min               19.0     50.000000
# 25%               19.0    132.250000
# 50%               19.0    163.000000
# 75%               19.0    198.500000
# max               19.0    274.000000

# %%
mp73.describe()
# Out:
#        ARREST_PRECINCT  M_ARREST_NUM
# count             66.0     66.000000
# mean              73.0    328.090909
# std                0.0    103.048118
# min               73.0    127.000000
# 25%               73.0    244.500000
# 50%               73.0    333.500000
# 75%               73.0    404.750000
# max               73.0    523.000000

# %%
# taking a look at the distribution of the data

# precinct 19
plt.hist(mp19['M_ARREST_NUM'], bins=10, edgecolor='black')
plt.show()

# %%
# and for precinct 73

plt.hist(mp73['M_ARREST_NUM'], bins=10, edgecolor='black')
plt.show()

# %%
# assuming this data meets conditions for the t-test (normality, similar variances, independent), I'll run the test
import scipy.stats as stats

ues = mp19['M_ARREST_NUM']
br = mp73['M_ARREST_NUM']
t_stat, p_value = stats.ttest_ind(ues, br)

print(f'T-statistic: {t_stat}')
print(f'P-value: {p_value}')
# Out:
# T-statistic: -12.051550677757769
# P-value: 6.384527137082858e-23

# %%
#mp19['ARREST_MONTH'] = pd.to_datetime(mp19['ARREST_MONTH'].dt.to_timestamp())
#mp73['ARREST_MONTH'] = pd.to_datetime(mp73['ARREST_MONTH'].dt.to_timestamp())

fig = go.Figure()

# Add traces for each dataset
fig.add_trace(go.Scatter(x=mp19['ARREST_MONTH'], y=mp19['M_ARREST_NUM'], mode='lines+markers', name='Precinct 19 (Upper East Side)'))
fig.add_trace(go.Scatter(x=mp73['ARREST_MONTH'], y=mp73['M_ARREST_NUM'], mode='lines+markers', name='Precinct 73 (Brownsville)'))


# Formatting the plot
fig.update_layout(
    title="Monthly Arrest Data for Upper East Side and Brownsville Precincts",
    xaxis_title="Month",
    yaxis_title="Count",
    hovermode="x unified"
)

# Show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41b6326d-4716-4ba5-af91-1ddc467980d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41b6326d-4716-4ba5-af91-1ddc467980d0")) {                    Plotly.newPlot(                        "41b6326d-4716-4ba5-af91-1ddc467980d0",                        [{"mode":"lines+markers","name":"Precinct 19 (Upper East Side)","x":["2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00"],"y":[201,208,187,185,224,222,215,199,201,274,207,145,183,173,152,85,127,99,50,92,135,120,164,110,119,119,152,110,110,132,133,98,158,137,141,140,138,129,174,183,209,179,171,222,203,232,159,197,147,197,174,151,207,170,129,121,124,143,162,149,204,172,220,180,213,172],"type":"scatter"},{"mode":"lines+markers","name":"Precinct 73 (Brownsville)","x":["2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00"],"y":[462,384,376,381,417,314,394,404,318,371,342,246,297,274,270,244,315,134,127,204,194,240,229,248,260,191,261,13 ...

# %%
fig.write_html("Figure 3.html")
files.download("Figure 3.html")

# %% [markdown]
# Q3: In taking samples of the data from both precincts, we can reject the null hypothesis stated earlier that there is no difference in the arrest rates between these two precincts. The p-value suggests that we have sufficient evidence to conclude that there is a significant difference in arrests between precincts.
